# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
# define time range 
start = '2000-01-01' # format: YYYY-MM-DD
end = dt.datetime.now() # today

# %%
# favorite stock symbol 
#stock='AMD'
stock='^NSEI'

#stock='^NSEBANK'

# %%
df = yf.download(stock,start, end, interval='1d')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098  4732.350098
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805  4747.549805
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805  4837.549805
#
#             Volume
# Date
# 2007-09-17       0
# 2007-09-18       0
# 2007-09-19       0
# 2007-09-20       0
# 2007-09-21       0

# %%
# Let's calulate Simple Moving Average(SMA)
short_sma= 20
long_sma = 50
SMAs=[short_sma, long_sma]

# %%
for i in SMAs:
    df["SMA_"+str(i)]= df.iloc[:,4].rolling(window=i).mean()

# %%
df.tail(3)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-07-06  15818.200195  16011.349609  15800.900391  15989.799805
# 2022-07-07  16113.750000  16150.500000  16045.950195  16132.900391
# 2022-07-08  16273.650391  16275.500000  16157.900391  16220.599609
#
#                Adj Close  Volume        SMA_20        SMA_50
# Date
# 2022-07-06  15989.799805  288400  15742.022412  16139.901055
# 2022-07-07  16132.900391  264600  15724.762451  16121.791055
# 2022-07-08  16220.599609       0  15725.702441  16101.302031

# %%
position=0 # 1 means we have already entered poistion, 0 means not already entered
counter=0
percentChange=[]   # empty list to collect %changes 
for i in df.index:
    SMA_short=df['SMA_20']
    SMA_long =df['SMA_50']
    close=df['Adj Close'][i]
    
    if(SMA_short[i] > SMA_long[i]):
        print('Up trend')
        if(position==0):
            buyP=close   #buy price
            position=1   # turn position
            print("Buy at the price"+str(buyP))
        
    elif(SMA_short[i] < SMA_long[i]):
        print('Down trend')
        if(position==1):   # have a poistion in down trend
            position=0     # selling position
            sellP=close    # sell price
            print("Sell at the price"+str(sellP))
            perc=(sellP/buyP-1)*100
            percentChange.append(perc)
    if(counter==df["Adj Close"].count()-1 and position==1):
        position=0
        sellP=close
        print("Sell at the price"+str(sellP))
        perc=(sellP/buyP-1)*100
        percentChange.append(perc)

    counter+=1
print(percentChange)
# Out:
# Up trend
# Buy at the price5698.14990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5274.10009765625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5192.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price4627.7998046875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price4552.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price4038.14990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price2959.14990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price2783.89990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price3060.35009765625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price4233.5
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price4694.14990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5058.0498046875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5122.0
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price4845.35009765625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5245.89990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5156.64990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5323.14990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5751.9501953125
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5736.35009765625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5420.60009765625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5616.10009765625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5118.5
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5191.60009765625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price4936.85009765625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5158.2998046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5178.85009765625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5149.14990234375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5850.2998046875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price6069.2998046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5655.89990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5990.5
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price5699.2998046875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price5873.85009765625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price6000.89990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price6537.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price7995.89990234375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8344.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price8395.4501953125
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8835.599609375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price8342.150390625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8510.7998046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price7880.7001953125
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8261.650390625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price7849.25
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price7704.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price8659.099609375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8412.7998046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price9934.7998046875
# Down trend
# Up trend
# Buy at the price10093.0498046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price10440.2998046875
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price10530.7001953125
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price10554.2998046875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price10614.349609375
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price10930.4501953125
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price10876.75
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price10789.849609375
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price10806.650390625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price11844.099609375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price12021.650390625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price11419.25
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price11474.4501953125
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price12107.900390625
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price8823.25
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price14683.5
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price14906.0498046875
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price17536.25
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price18255.75
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price17352.44921875
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Up trend
# Buy at the price17957.400390625
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Up trend
# Down trend
# Sell at the price16167.099609375
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# Down trend
# [-7.441885734053444, -10.871013439501176, -11.293318637075078, -5.922308966544609, 38.33384628909613, 7.752200290026057, -5.401208558058379, -1.7013286883366785, 8.05538639405874, -5.5043711528173445, -8.860242677368092, -4.906965005162989, 0.39839276015083414, 13.616808903244525, -6.811327758507979, -4.861033224480426, 2.162973221570552, 22.31289766100042, 0.6135985296761293, -5.584784740884208, -7.403529912993134, -4.991743430501194, 12.393803541876247, 18.091480070070865, 3.440486341786664, 0.22410294602732694, 2.978049504402125, -0.7989554841749569, 9.600099764955928, -5.010962480615621, 5.52052764646862, 66.41826991188053, 17.64518587939632, -4.9480343521904, -9.969710215876571]

# %%
gains=0
numGains=0
losses=0
numLosses=0
totReturn=1
for i in percentChange:
    if(i>0):
        gains+=i
        numGains+=1
    else:
        losses+=i
        numLosses+=1
    totReturn = totReturn*((i/100)+1)
totReturn=round((totReturn-1)*100,2)
print("This statistics is from "+str(df.index[0])+" up to now with "+str(numGains+numLosses)+" trades:")
print("SMAs used: "+str(SMAs))
print("Total return over "+str(numGains+numLosses)+ " trades: "+ str(totReturn)+"%" )
# Out:
# This statistics is from 2007-09-17 00:00:00 up to now with 35 trades:
# SMAs used: [20, 50]
# Total return over 35 trades: 130.74%

# %%
if (numGains>0):
    avgGain=gains/numGains
    maxReturn= str(max(percentChange))
else:
    avgGain=0
    maxReturn='unknown'

if(numLosses>0):
    avgLoss=losses/numLosses
    maxLoss=str(min(percentChange))
    ratioRR=str(-avgGain/avgLoss)  # risk-reward ratio
else:
    avgLoss=0
    maxLoss='unknown'
    ratioRR='inf'
print("Average Gain: "+ str(avgGain))
print("Average Loss: "+ str(avgLoss))
print("Max Return: "+ maxReturn)
print("Max Loss: "+ maxLoss)
print("Gain/loss ratio: "+ ratioRR)
# Out:
# Average Gain: 13.503418215040472
# Average Loss: -6.237929136619014
# Max Return: 66.41826991188053
# Max Loss: -11.293318637075078
# Gain/loss ratio: 2.1647277356471197

# %%
if(numGains>0 or numLosses>0):
    batAvg=numGains/(numGains+numLosses)
else:
    batAvg=0
print("Batting Avg: "+ str(batAvg))
# Out:
# Batting Avg: 0.4857142857142857

# %%
mpf.plot(df, type = 'ohlc',figratio=(16,6), mav=(short_sma,long_sma), 
         volume=True, title= str(stock), style='default')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\mplfinance\_arg_validators.py:36: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
